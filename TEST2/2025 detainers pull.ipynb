# %% [markdown]
# ### CONTEXT:
# So, I have the data from Sandra Fish on Colorado removals. Now, the code itself looks like it already starts with clean data for a specific year. But it uses data from Arrests, Detainers, Detentions, Encounters, AND removals.
#
# Now pulling that for each year for each category is a lot. So for the sake of time and exploration, i am first going to pull just 2025 data in this sheet so i can start analyzingand see if my analysis is correct.
#
# ### In this notebook I will:
# 1. Pull data from the Deportation Data Project
# 2. Extract ICE Detainers for 2025

# %%
## import necessary libraries
import pandas as pd

# %% [markdown]
# ### Extraction 1: 2025 detainers data

# %%
df1 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICE Arrests/CLEANED-ICEarrests-Albany/TEST2/RawData/Detainers/2026-ICLI-00005_Detainers_FY24_20260311_Redacted.xlsx')
df1
# Out:
#                        ERO LESA Statistical Tracking Unit     Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional            NaN
# 1       Deportation Data Project - 2026-ICLI-00005 – 0...            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                           ERO Detainers Prepared FY2024            NaN
# ...                                                   ...            ...
# 147245                                2024-09-30 00:00:00     CALIFORNIA
# 147246                                2024-09-30 00:00:00  MASSACHUSETTS
# 147247                                2024-09-30 00:00:00  MASSACHUSETTS
# 147248                                2024-09-30 00:00:00          TEXAS
# 147249                                2023-10-13 00:00:00     CALIFORNIA
#
#                                   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                        NaN        NaN        NaN        NaN
# 1                                        NaN        NaN        NaN        NaN
# 2                                        NaN        NaN        NaN        NaN
# 3                                        NaN        NaN        NaN        NaN
# 4                                        NaN        NaN        NaN        NaN
# ...                                      ...        ...        ...        ...
# 147245  San Francisco Area of Responsibility        NaN        NaN        NaN
# 147246         Boston Area of Responsibility        NaN        NaN        NaN
# 147247         Boston Area of Responsibility        NaN        NaN        NaN
# 147248      Harlingen Area of Responsibility        NaN        NaN        NaN
# 147249    Los Angeles Area of Responsibility        NaN        NaN        NaN
#
#        Unnamed: 6                    Unnamed: 7                Unnamed: 8  \
# 0             NaN                           NaN                       NaN
# 1             NaN                           NaN                       NaN
# 2             NaN                           NaN                       NaN
# 3             NaN                           NaN                       NaN
# 4             NaN                           NaN                       NaN
# ...           ...                           ...                       ...
# 147245        NaN    2 Pending Criminal Charges  RIVERSIDE COUNTY SHERIFF
# 147246        NaN    2 Pending Criminal Charges     CAMBRIDGE POLICE DEPT
# 147247        NaN    2 Pending Criminal Charges          SUFFOLK HOC SBAY
# 147248        NaN    2 Pending Criminal Charges     SAN JUAN POLICE DEPT.
# 147249        NaN  3 Other Immigration Violator      VENTURA CUSTODY CASE
#
#        Unnamed: 9  ... Unnamed: 54  \
# 0             NaN  ...         NaN
# 1             NaN  ...         NaN
# 2             NaN  ...         NaN
# 3             NaN  ...         NaN
# 4             NaN  ...         NaN
# ...           ...  ...         ...
# 147245    RIVERCA  ...         YES
# 147246    CAMPDMA  ...         YES
# 147247    SUFFOMA  ...         YES
# 147248    SJUANTX  ...          NO
# 147249    VENHOLD  ...         YES
#
#                                           Unnamed: 55 Unnamed: 56 Unnamed: 57  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# ...                                               ...         ...         ...
# 147245  No longer in State, Local, or Federal Custody           G         NaN
# 147246                       Detainer Declined by LEA           A         NaN
# 147247                  Superseding - New Form Issued           W         NaN
# 147248                          Booked into Detention           B         NaN
# 147249                                            NaN         NaN         NaN
#
#        Unnamed: 58                                        Unnamed: 59  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ...            ...                                                ...
# 147245         NaN  I247G - Request for Advance Notification of Re...
# 147246         NaN  I247G - Request for Advance Notification of Re...
# 147247         NaN  I247G - Request for Advance Notification of Re...
# 147248         NaN  I247A - Immigration Detainer - Immigration Det...
# 147249         NaN  I247G - Request for Advance Notification of Re...
#
#        Unnamed: 60                                Unnamed: 61  Unnamed: 62  \
# 0              NaN                                        NaN          NaN
# 1              NaN                                        NaN          NaN
# 2              NaN                                        NaN          NaN
# 3              NaN                                        NaN          NaN
# 4              NaN                                        NaN          NaN
# ...            ...                                        ...          ...
# 147245         NaN  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147246         NaN  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147247         NaN  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147248         NaN       HARLINGEN, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 147249         NaN  ERO - Pacific Enforcement Response Center  b(6), b(7)c
#
#        Unnamed: 63
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 147245         NaN
# 147246         NaN
# 147247         NaN
# 147248         NaN
# 147249         NaN
#
# [147250 rows x 64 columns]

# %%
#### As you can see: we don't need the first couple rows, it has unneeded rows. Let's remove the rows
df1 = df1.iloc[5:]
df1
# Out:
#        ERO LESA Statistical Tracking Unit      Unnamed: 1  \
# 5                   Detainer Prepare Date  Facility State
# 6                     2024-05-11 00:00:00        NEW YORK
# 7                     2024-03-12 00:00:00         FLORIDA
# 8                     2024-01-10 00:00:00           TEXAS
# 9                     2023-11-03 00:00:00         FLORIDA
# ...                                   ...             ...
# 147245                2024-09-30 00:00:00      CALIFORNIA
# 147246                2024-09-30 00:00:00   MASSACHUSETTS
# 147247                2024-09-30 00:00:00   MASSACHUSETTS
# 147248                2024-09-30 00:00:00           TEXAS
# 147249                2023-10-13 00:00:00      CALIFORNIA
#
#                                   Unnamed: 2  \
# 5                               Facility AOR
# 6                                        NaN
# 7               Miami Area of Responsibility
# 8                                        NaN
# 9               Miami Area of Responsibility
# ...                                      ...
# 147245  San Francisco Area of Responsibility
# 147246         Boston Area of Responsibility
# 147247         Boston Area of Responsibility
# 147248      Harlingen Area of Responsibility
# 147249    Los Angeles Area of Responsibility
#
#                                    Unnamed: 3         Unnamed: 4  \
# 5                           Port of Departure  Departure Country
# 6                                         NaN                NaN
# 7       ALEXANDRIA INTERNATIONAL AIRPORT, POE          NICARAGUA
# 8       ALEXANDRIA INTERNATIONAL AIRPORT, POE           HONDURAS
# 9                BROWNSVILLE-MATAMOR, TX, POE             MEXICO
# ...                                       ...                ...
# 147245                                    NaN                NaN
# 147246                                    NaN                NaN
# 147247                                    NaN                NaN
# 147248                                    NaN                NaN
# 147249                                    NaN                NaN
#
#                  Unnamed: 5                            Unnamed: 6  \
# 5             Departed Date                           Case Status
# 6                       NaN                                ACTIVE
# 7       2024-08-22 00:00:00  8-Excluded/Removed - Inadmissibility
# 8       2024-07-01 00:00:00       3-Voluntary Departure Confirmed
# 9       2023-12-20 00:00:00  8-Excluded/Removed - Inadmissibility
# ...                     ...                                   ...
# 147245                  NaN                                   NaN
# 147246                  NaN                                   NaN
# 147247                  NaN                                   NaN
# 147248                  NaN                                   NaN
# 147249                  NaN                                   NaN
#
#                           Unnamed: 7                        Unnamed: 8  \
# 5               Detainer Criminality                 Detainer Facility
# 6         2 Pending Criminal Charges     GOSHEN TOWN POLICE DEPARTMENT
# 7         2 Pending Criminal Charges  TURNER GUIFORD KNIGHT (TGK) JAIL
# 8               1 Convicted Criminal                HARRIS COUNTY JAIL
# 9         2 Pending Criminal Charges            PALM BEACH COUNTY JAIL
# ...                              ...                               ...
# 147245    2 Pending Criminal Charges          RIVERSIDE COUNTY SHERIFF
# 147246    2 Pending Criminal Charges             CAMBRIDGE POLICE DEPT
# 147247    2 Pending Criminal Charges                  SUFFOLK HOC SBAY
# 147248    2 Pending Criminal Charges             SAN JUAN POLICE DEPT.
# 147249  3 Other Immigration Violator              VENTURA CUSTODY CASE
#
#                     Unnamed: 9  ...            Unnamed: 54  \
# 5       Detainer Facility Code  ...  Resume Custody Yes No
# 6                      GOSTPNY  ...                    YES
# 7                      TGKJLFL  ...                     NO
# 8                      HARISTX  ...                     NO
# 9                      PALMBFL  ...                     NO
# ...                        ...  ...                    ...
# 147245                 RIVERCA  ...                    YES
# 147246                 CAMPDMA  ...                    YES
# 147247                 SUFFOMA  ...                    YES
# 147248                 SJUANTX  ...                     NO
# 147249                 VENHOLD  ...                    YES
#
#                                           Unnamed: 55  \
# 5                                Detainer Lift Reason
# 6                                                 NaN
# 7                               Booked into Detention
# 8                               Booked into Detention
# 9                               Booked into Detention
# ...                                               ...
# 147245  No longer in State, Local, or Federal Custody
# 147246                       Detainer Declined by LEA
# 147247                  Superseding - New Form Issued
# 147248                          Booked into Detention
# 147249                                            NaN
#
#                       Unnamed: 56                  Unnamed: 57  \
# 5       Detainer Lift Reason Code  Active Investigation Yes No
# 6                             NaN                          NaN
# 7                               B                          NaN
# 8                               B                          NaN
# 9                               B                          NaN
# ...                           ...                          ...
# 147245                          G                          NaN
# 147246                          A                          NaN
# 147247                          W                          NaN
# 147248                          B                          NaN
# 147249                        NaN                          NaN
#
#                        Unnamed: 58  \
# 5       Arrest Warrant Served Date
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# ...                            ...
# 147245                         NaN
# 147246                         NaN
# 147247                         NaN
# 147248                         NaN
# 147249                         NaN
#
#                                               Unnamed: 59  \
# 5                                           Detainer Type
# 6       I247G - Request for Advance Notification of Re...
# 7       I247A - Immigration Detainer - Immigration Det...
# 8       I247A - Immigration Detainer - Immigration Det...
# 9       I247A - Immigration Detainer - Immigration Det...
# ...                                                   ...
# 147245  I247G - Request for Advance Notification of Re...
# 147246  I247G - Request for Advance Notification of Re...
# 147247  I247G - Request for Advance Notification of Re...
# 147248  I247A - Immigration Detainer - Immigration Det...
# 147249  I247G - Request for Advance Notification of Re...
#
#                           Unnamed: 60  \
# 5       Notify Release Request Yes No
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# ...                               ...
# 147245                            NaN
# 147246                            NaN
# 147247                            NaN
# 147248                            NaN
# 147249                            NaN
#
#                                       Unnamed: 61  Unnamed: 62  \
# 5                           TOD Current Duty Site   EID DTA ID
# 6       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 7                  ERO - Bradenton, FL Sub Office  b(6), b(7)c
# 8          ERO - Montgomery County, TX Sub Office  b(6), b(7)c
# 9                     ERO - Stuart, FL Sub Office  b(6), b(7)c
# ...                                           ...          ...
# 147245  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147246  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147247  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147248       HARLINGEN, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 147249  ERO - Pacific Enforcement Response Center  b(6), b(7)c
#
#                                      Unnamed: 63
# 5                          Anonymized Identifier
# 6       00007dba409d3f00c75cd759758cb37d34872e8b
# 7       00035fe86dad009640790712354636d76b838c7c
# 8       0003826317c1318abeffb0c01095af6825552b60
# 9       00038f76045b3d1bb8b62d85365e29a9924a58f1
# ...                                          ...
# 147245                                       NaN
# 147246                                       NaN
# 147247                                       NaN
# 147248                                       NaN
# 147249                                       NaN
#
# [147245 rows x 64 columns]

# %%
## the first row is actually the header we want. Let's drop the header and put the actual header we want there
## create a new df, just to be safe
df1.columns = df1.iloc[0]
df1_titled = df1[1:].reset_index(drop=True)
df1_titled
# Out:
# 5      Detainer Prepare Date Facility State  \
# 0        2024-05-11 00:00:00       NEW YORK
# 1        2024-03-12 00:00:00        FLORIDA
# 2        2024-01-10 00:00:00          TEXAS
# 3        2023-11-03 00:00:00        FLORIDA
# 4        2023-10-13 00:00:00       VIRGINIA
# ...                      ...            ...
# 147239   2024-09-30 00:00:00     CALIFORNIA
# 147240   2024-09-30 00:00:00  MASSACHUSETTS
# 147241   2024-09-30 00:00:00  MASSACHUSETTS
# 147242   2024-09-30 00:00:00          TEXAS
# 147243   2023-10-13 00:00:00     CALIFORNIA
#
# 5                               Facility AOR  \
# 0                                        NaN
# 1               Miami Area of Responsibility
# 2                                        NaN
# 3               Miami Area of Responsibility
# 4          Washington Area of Responsibility
# ...                                      ...
# 147239  San Francisco Area of Responsibility
# 147240         Boston Area of Responsibility
# 147241         Boston Area of Responsibility
# 147242      Harlingen Area of Responsibility
# 147243    Los Angeles Area of Responsibility
#
# 5                           Port of Departure Departure Country  \
# 0                                         NaN               NaN
# 1       ALEXANDRIA INTERNATIONAL AIRPORT, POE         NICARAGUA
# 2       ALEXANDRIA INTERNATIONAL AIRPORT, POE          HONDURAS
# 3                BROWNSVILLE-MATAMOR, TX, POE            MEXICO
# 4                                         NaN               NaN
# ...                                       ...               ...
# 147239                                    NaN               NaN
# 147240                                    NaN               NaN
# 147241                                    NaN               NaN
# 147242                                    NaN               NaN
# 147243                                    NaN               NaN
#
# 5             Departed Date                           Case Status  \
# 0                       NaN                                ACTIVE
# 1       2024-08-22 00:00:00  8-Excluded/Removed - Inadmissibility
# 2       2024-07-01 00:00:00       3-Voluntary Departure Confirmed
# 3       2023-12-20 00:00:00  8-Excluded/Removed - Inadmissibility
# 4                       NaN                                   NaN
# ...                     ...                                   ...
# 147239                  NaN                                   NaN
# 147240                  NaN                                   NaN
# 147241                  NaN                                   NaN
# 147242                  NaN                                   NaN
# 147243                  NaN                                   NaN
#
# 5               Detainer Criminality                 Detainer Facility  \
# 0         2 Pending Criminal Charges     GOSHEN TOWN POLICE DEPARTMENT
# 1         2 Pending Criminal Charges  TURNER GUIFORD KNIGHT (TGK) JAIL
# 2               1 Convicted Criminal                HARRIS COUNTY JAIL
# 3         2 Pending Criminal Charges            PALM BEACH COUNTY JAIL
# 4         2 Pending Criminal Charges             CHESTERFIELD CO. JAIL
# ...                              ...                               ...
# 147239    2 Pending Criminal Charges          RIVERSIDE COUNTY SHERIFF
# 147240    2 Pending Criminal Charges             CAMBRIDGE POLICE DEPT
# 147241    2 Pending Criminal Charges                  SUFFOLK HOC SBAY
# 147242    2 Pending Criminal Charges             SAN JUAN POLICE DEPT.
# 147243  3 Other Immigration Violator              VENTURA CUSTODY CASE
#
# 5      Detainer Facility Code  ... Resume Custody Yes No  \
# 0                     GOSTPNY  ...                   YES
# 1                     TGKJLFL  ...                    NO
# 2                     HARISTX  ...                    NO
# 3                     PALMBFL  ...                    NO
# 4                     CHFLDVA  ...                   YES
# ...                       ...  ...                   ...
# 147239                RIVERCA  ...                   YES
# 147240                CAMPDMA  ...                   YES
# 147241                SUFFOMA  ...                   YES
# 147242                SJUANTX  ...                    NO
# 147243                VENHOLD  ...                   YES
#
# 5                                Detainer Lift Reason  \
# 0                                                 NaN
# 1                               Booked into Detention
# 2                               Booked into Detention
# 3                               Booked into Detention
# 4       No longer in State, Local, or Federal Custody
# ...                                               ...
# 147239  No longer in State, Local, or Federal Custody
# 147240                       Detainer Declined by LEA
# 147241                  Superseding - New Form Issued
# 147242                          Booked into Detention
# 147243                                            NaN
#
# 5      Detainer Lift Reason Code Active Investigation Yes No  \
# 0                            NaN                         NaN
# 1                              B                         NaN
# 2                              B                         NaN
# 3                              B                         NaN
# 4                              G                         NaN
# ...                          ...                         ...
# 147239                         G                         NaN
# 147240                         A                         NaN
# 147241                         W                         NaN
# 147242                         B                         NaN
# 147243                       NaN                         NaN
#
# 5      Arrest Warrant Served Date  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 147239                        NaN
# 147240                        NaN
# 147241                        NaN
# 147242                        NaN
# 147243                        NaN
#
# 5                                           Detainer Type  \
# 0       I247G - Request for Advance Notification of Re...
# 1       I247A - Immigration Detainer - Immigration Det...
# 2       I247A - Immigration Detainer - Immigration Det...
# 3       I247A - Immigration Detainer - Immigration Det...
# 4       I247G - Request for Advance Notification of Re...
# ...                                                   ...
# 147239  I247G - Request for Advance Notification of Re...
# 147240  I247G - Request for Advance Notification of Re...
# 147241  I247G - Request for Advance Notification of Re...
# 147242  I247A - Immigration Detainer - Immigration Det...
# 147243  I247G - Request for Advance Notification of Re...
#
# 5      Notify Release Request Yes No  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 147239                           NaN
# 147240                           NaN
# 147241                           NaN
# 147242                           NaN
# 147243                           NaN
#
# 5                           TOD Current Duty Site   EID DTA ID  \
# 0       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 1                  ERO - Bradenton, FL Sub Office  b(6), b(7)c
# 2          ERO - Montgomery County, TX Sub Office  b(6), b(7)c
# 3                     ERO - Stuart, FL Sub Office  b(6), b(7)c
# 4       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# ...                                           ...          ...
# 147239  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147240  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147241  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 147242       HARLINGEN, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 147243  ERO - Pacific Enforcement Response Center  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 0       00007dba409d3f00c75cd759758cb37d34872e8b
# 1       00035fe86dad009640790712354636d76b838c7c
# 2       0003826317c1318abeffb0c01095af6825552b60
# 3       00038f76045b3d1bb8b62d85365e29a9924a58f1
# 4       0003ea57100be8d7c57c2a799f9fb12253d66e20
# ...                                          ...
# 147239                                       NaN
# 147240                                       NaN
# 147241                                       NaN
# 147242                                       NaN
# 147243                                       NaN
#
# [147244 rows x 64 columns]

# %%
## to be safe, let's turn the time, which is what we need, into datetime
## turn the column into datetime
df1_titled['Departed Date'] = pd.to_datetime(df1_titled['Departed Date'])

# %%
## create a subset of data for only 2022
##first: pull anything before 2023
df_2025pt1 = df1_titled[df1_titled['Departed Date'] < '2026-01-01']

# %%
##now: pull anything after 2021 from the same subset. 
df_2025pt1 = df_2025pt1[df_2025pt1['Departed Date'] > '2024-12-31']

# %%
##This is your 2025 ICE detainers data
df_2025pt1
# Out:
# 5      Detainer Prepare Date Facility State  \
# 28       2024-07-08 00:00:00       ARKANSAS
# 35       2024-01-28 00:00:00       VIRGINIA
# 40       2024-03-27 00:00:00          TEXAS
# 46       2024-06-10 00:00:00        ARIZONA
# 47       2024-08-12 00:00:00        ARIZONA
# ...                      ...            ...
# 141864   2024-06-28 00:00:00       VIRGINIA
# 143257   2024-07-22 00:00:00       VIRGINIA
# 144337   2024-08-11 00:00:00  MASSACHUSETTS
# 145107   2024-08-25 00:00:00        GEORGIA
# 146281   2024-09-13 00:00:00       MARYLAND
#
# 5                             Facility AOR  \
# 28      New Orleans Area of Responsibility
# 35       Washington Area of Responsibility
# 40           Dallas Area of Responsibility
# 46          Phoenix Area of Responsibility
# 47          Phoenix Area of Responsibility
# ...                                    ...
# 141864   Washington Area of Responsibility
# 143257   Washington Area of Responsibility
# 144337       Boston Area of Responsibility
# 145107      Atlanta Area of Responsibility
# 146281                                 NaN
#
# 5                                 Port of Departure   Departure Country  \
# 28            ALEXANDRIA INTERNATIONAL AIRPORT, POE           GUATEMALA
# 35            ALEXANDRIA INTERNATIONAL AIRPORT, POE           GUATEMALA
# 40            ALEXANDRIA INTERNATIONAL AIRPORT, POE         EL SALVADOR
# 46                                 NOGALES, AZ, POE              MEXICO
# 47                                 NOGALES, AZ, POE              MEXICO
# ...                                             ...                 ...
# 141864          WASHINGTON, DC, DULLES AIRPORT, POE           GUATEMALA
# 143257          WASHINGTON, DC, DULLES AIRPORT, POE           GUATEMALA
# 144337  LOGAN INTERNATIONAL AIRPORT, BOSTON MA, POE  DOMINICAN REPUBLIC
# 145107                           HARLINGEN, TX, POE              MEXICO
# 146281                                          NaN                 NaN
#
# 5      Departed Date                           Case Status  \
# 28        2025-04-01  8-Excluded/Removed - Inadmissibility
# 35        2025-02-26    6-Deported/Removed - Deportability
# 40        2025-10-07  8-Excluded/Removed - Inadmissibility
# 46        2025-01-08  8-Excluded/Removed - Inadmissibility
# 47        2025-01-08  8-Excluded/Removed - Inadmissibility
# ...              ...                                   ...
# 141864    2025-02-23  8-Excluded/Removed - Inadmissibility
# 143257    2025-02-23  8-Excluded/Removed - Inadmissibility
# 144337    2025-05-08    6-Deported/Removed - Deportability
# 145107    2025-07-18    6-Deported/Removed - Deportability
# 146281    2025-05-28                                7-Died
#
# 5               Detainer Criminality            Detainer Facility  \
# 28      3 Other Immigration Violator  PULASKI COUNTY REG.DET.FAC.
# 35              1 Convicted Criminal               PRINCE WILLIAM
# 40        2 Pending Criminal Charges          IRVING POLICE DEPT.
# 46              1 Convicted Criminal         MARICOPA COUNTY JAIL
# 47              1 Convicted Criminal         US MARSHAL - PHOENIX
# ...                              ...                          ...
# 141864    2 Pending Criminal Charges            ARLINGTON CO JAIL
# 143257    2 Pending Criminal Charges         ALEXANDRIA CITY JAIL
# 144337    2 Pending Criminal Charges    ESSEX CO. JAIL, MIDDLETON
# 145107    2 Pending Criminal Charges         ATKINSON COUNTY JAIL
# 146281    2 Pending Criminal Charges    PRINCE GEORGES CO DET CEN
#
# 5      Detainer Facility Code  ... Resume Custody Yes No  \
# 28                    PULASAR  ...                    NO
# 35                    PWILLVA  ...                    NO
# 40                    IRVNGTX  ...                    NO
# 46                    MCFAJAZ  ...                    NO
# 47                     USMPHO  ...                    NO
# ...                       ...  ...                   ...
# 141864                ARLCOVA  ...                   YES
# 143257                ALEXAVA  ...                    NO
# 144337                ESSEXMA  ...                    NO
# 145107                ATKNSGA  ...                   YES
# 146281                PRINCMD  ...                    NO
#
# 5                                Detainer Lift Reason  \
# 28                              Booked into Detention
# 35                           Detainer Declined by LEA
# 40                              Booked into Detention
# 46                              Booked into Detention
# 47                              Booked into Detention
# ...                                               ...
# 141864  No longer in State, Local, or Federal Custody
# 143257  No longer in State, Local, or Federal Custody
# 144337                       Detainer Declined by LEA
# 145107                          Booked into Detention
# 146281                     Insufficient Notice to ICE
#
# 5      Detainer Lift Reason Code Active Investigation Yes No  \
# 28                             B                         NaN
# 35                             A                         NaN
# 40                             B                         NaN
# 46                             B                         NaN
# 47                             B                         NaN
# ...                          ...                         ...
# 141864                         G                         NaN
# 143257                         G                         NaN
# 144337                         A                         NaN
# 145107                         B                         NaN
# 146281                         O                         NaN
#
# 5      Arrest Warrant Served Date  \
# 28                            NaN
# 35                            NaN
# 40                            NaN
# 46                            NaN
# 47                            NaN
# ...                           ...
# 141864                        NaN
# 143257                        NaN
# 144337                        NaN
# 145107                        NaN
# 146281                        NaN
#
# 5                                           Detainer Type  \
# 28      I247A - Immigration Detainer - Immigration Det...
# 35      I247A - Immigration Detainer - Immigration Det...
# 40      I247A - Immigration Detainer - Immigration Det...
# 46      I247A - Immigration Detainer - Immigration Det...
# 47      I247A - Immigration Detainer - Immigration Det...
# ...                                                   ...
# 141864  I247G - Request for Advance Notification of Re...
# 143257  I247A - Immigration Detainer - Immigration Det...
# 144337  I247A - Immigration Detainer - Immigration Det...
# 145107  I247G - Request for Advance Notification of Re...
# 146281  I247A - Immigration Detainer - Immigration Det...
#
# 5      Notify Release Request Yes No  \
# 28                               NaN
# 35                               NaN
# 40                               NaN
# 46                               NaN
# 47                               NaN
# ...                              ...
# 141864                           NaN
# 143257                           NaN
# 144337                           NaN
# 145107                           NaN
# 146281                           NaN
#
# 5                           TOD Current Duty Site   EID DTA ID  \
# 28      ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 35      ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 40              DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 46             PHOENIX, AZ, DOCKET CONTROL OFFICE  b(6), b(7)c
# 47             PHOENIX, AZ, DOCKET CONTROL OFFICE  b(6), b(7)c
# ...                                           ...          ...
# 141864  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 143257      WASHINGTON, DC, Docket Control Office  b(6), b(7)c
# 144337          BOSTON, MA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 145107  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 146281       BALTIMORE, MD, DOCKET CONTROL OFFICE  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 28      00103f3e74679b755da13514ecf999d52ef39c4e
# 35      0015da563be4d6695f33804021144210bade49dd
# 40      00197c0df52a1bb3936347d6dc9816c997a2fb38
# 46      001d1303978e35d722d597f0e15f5692dd5286df
# 47      001d1303978e35d722d597f0e15f5692dd5286df
# ...                                          ...
# 141864                                       NaN
# 143257                                       NaN
# 144337                                       NaN
# 145107                                       NaN
# 146281                                       NaN
#
# [14122 rows x 64 columns]

# %%
##Let us do Extraction 1: 2025 ICE Detainers data
df_2025pt1.to_csv('FilteredData/2025ICEDetainersData1.csv', index=False)

# %%
##Ok, to be safe, let's check the file 2 in the zip folder for stray 2022 arrests and then start looking for 2023 data as well
df2 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICE Arrests/CLEANED-ICEarrests-Albany/TEST2/RawData/Detainers/2026-ICLI-00005_Detainers_FY25_20260311_Redacted.xlsx')
df2
# Out:
#                        ERO LESA Statistical Tracking Unit      Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional             NaN
# 1       Deportation Data Project - 2026-ICLI-00005 – 0...             NaN
# 2                                                     NaN             NaN
# 3                                                     NaN             NaN
# 4                           ERO Detainers Prepared FY2025             NaN
# ...                                                   ...             ...
# 227123                                2025-09-30 00:00:00      CALIFORNIA
# 227124                                2025-09-30 00:00:00            UTAH
# 227125                                2025-02-25 00:00:00        ARKANSAS
# 227126                                2025-01-25 00:00:00  NORTH CAROLINA
# 227127                                2025-01-28 00:00:00  NORTH CAROLINA
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                         NaN        NaN        NaN
# 1                                         NaN        NaN        NaN
# 2                                         NaN        NaN        NaN
# 3                                         NaN        NaN        NaN
# 4                                         NaN        NaN        NaN
# ...                                       ...        ...        ...
# 227123   San Francisco Area of Responsibility        NaN        NaN
# 227124  Salt Lake City Area of Responsibility        NaN        NaN
# 227125     New Orleans Area of Responsibility        NaN        NaN
# 227126         Atlanta Area of Responsibility        NaN        NaN
# 227127         Atlanta Area of Responsibility        NaN        NaN
#
#        Unnamed: 5 Unnamed: 6                    Unnamed: 7  \
# 0             NaN        NaN                           NaN
# 1             NaN        NaN                           NaN
# 2             NaN        NaN                           NaN
# 3             NaN        NaN                           NaN
# 4             NaN        NaN                           NaN
# ...           ...        ...                           ...
# 227123        NaN        NaN    2 Pending Criminal Charges
# 227124        NaN        NaN    2 Pending Criminal Charges
# 227125        NaN        NaN  3 Other Immigration Violator
# 227126        NaN        NaN  3 Other Immigration Violator
# 227127        NaN     ACTIVE    2 Pending Criminal Charges
#
#                          Unnamed: 8 Unnamed: 9  ... Unnamed: 54  \
# 0                               NaN        NaN  ...         NaN
# 1                               NaN        NaN  ...         NaN
# 2                               NaN        NaN  ...         NaN
# 3                               NaN        NaN  ...         NaN
# 4                               NaN        NaN  ...         NaN
# ...                             ...        ...  ...         ...
# 227123  SANTA CLARA CO JAIL/ELMWOOD    SCMENCA  ...         YES
# 227124        SALT LAKE COUNTY JAIL    SLSLCUT  ...         YES
# 227125       CLARK COUNTY DETENTION    CLARKAR  ...          NO
# 227126          HAYWOOD COUNTY JAIL    HAYWDNC  ...          NO
# 227127          BUNCOMBE COUNTY DR.    BUNCONC  ...          NO
#
#                                           Unnamed: 55 Unnamed: 56 Unnamed: 57  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# ...                                               ...         ...         ...
# 227123  No longer in State, Local, or Federal Custody           G         NaN
# 227124                                            NaN         NaN         NaN
# 227125                                            NaN         NaN         NaN
# 227126                                  Early Release           Z         NaN
# 227127                                            NaN         NaN         NaN
#
#        Unnamed: 58                                        Unnamed: 59  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ...            ...                                                ...
# 227123         NaN  I247G - Request for Advance Notification of Re...
# 227124         NaN  I247G - Request for Advance Notification of Re...
# 227125         NaN  I247A - Immigration Detainer - Notice of Actio...
# 227126         NaN  I247A - Immigration Detainer - Notice of Actio...
# 227127         NaN  I247A - Immigration Detainer - Notice of Actio...
#
#        Unnamed: 60                                Unnamed: 61  Unnamed: 62  \
# 0              NaN                                        NaN          NaN
# 1              NaN                                        NaN          NaN
# 2              NaN                                        NaN          NaN
# 3              NaN                                        NaN          NaN
# 4              NaN                                        NaN          NaN
# ...            ...                                        ...          ...
# 227123         NaN  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 227124         NaN  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 227125         NaN             ERO - Texarkana, AR Sub Office  b(6), b(7)c
# 227126         NaN             ERO - Henderson, NC Sub Office  b(6), b(7)c
# 227127         NaN             ERO - Henderson, NC Sub Office  b(6), b(7)c
#
#        Unnamed: 63
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 227123         NaN
# 227124         NaN
# 227125         NaN
# 227126         NaN
# 227127         NaN
#
# [227128 rows x 64 columns]

# %%
#### As you can see: we don't need the first couple rows, it has unneeded rows. Let's remove the rows
df2 = df2.iloc[5:]
df2
# Out:
#        ERO LESA Statistical Tracking Unit      Unnamed: 1  \
# 5                   Detainer Prepare Date  Facility State
# 6                     2025-05-08 00:00:00      NEW JERSEY
# 7                     2024-10-28 00:00:00        VIRGINIA
# 8                     2024-10-31 00:00:00        VIRGINIA
# 9                     2024-11-03 00:00:00      CALIFORNIA
# ...                                   ...             ...
# 227123                2025-09-30 00:00:00      CALIFORNIA
# 227124                2025-09-30 00:00:00            UTAH
# 227125                2025-02-25 00:00:00        ARKANSAS
# 227126                2025-01-25 00:00:00  NORTH CAROLINA
# 227127                2025-01-28 00:00:00  NORTH CAROLINA
#
#                                    Unnamed: 2  \
# 5                                Facility AOR
# 6        New York City Area of Responsibility
# 7           Washington Area of Responsibility
# 8           Washington Area of Responsibility
# 9          Los Angeles Area of Responsibility
# ...                                       ...
# 227123   San Francisco Area of Responsibility
# 227124  Salt Lake City Area of Responsibility
# 227125     New Orleans Area of Responsibility
# 227126         Atlanta Area of Responsibility
# 227127         Atlanta Area of Responsibility
#
#                                    Unnamed: 3         Unnamed: 4  \
# 5                           Port of Departure  Departure Country
# 6                            EL PASO, TX, POE              SPAIN
# 7                                         NaN                NaN
# 8       ALEXANDRIA INTERNATIONAL AIRPORT, POE          GUATEMALA
# 9                                         NaN                NaN
# ...                                       ...                ...
# 227123                                    NaN                NaN
# 227124                                    NaN                NaN
# 227125                                    NaN                NaN
# 227126                                    NaN                NaN
# 227127                                    NaN                NaN
#
#                  Unnamed: 5                            Unnamed: 6  \
# 5             Departed Date                           Case Status
# 6       2025-09-08 00:00:00    6-Deported/Removed - Deportability
# 7                       NaN                                   NaN
# 8       2025-07-14 00:00:00  8-Excluded/Removed - Inadmissibility
# 9                       NaN                                   NaN
# ...                     ...                                   ...
# 227123                  NaN                                   NaN
# 227124                  NaN                                   NaN
# 227125                  NaN                                   NaN
# 227126                  NaN                                   NaN
# 227127                  NaN                                ACTIVE
#
#                           Unnamed: 7                   Unnamed: 8  \
# 5               Detainer Criminality            Detainer Facility
# 6         2 Pending Criminal Charges           BERGEN COUNTY JAIL
# 7               1 Convicted Criminal         CHESAPEAKE CITY JAIL
# 8               1 Convicted Criminal         CHESAPEAKE CITY JAIL
# 9               1 Convicted Criminal          DOWNEY POLICE DEPT.
# ...                              ...                          ...
# 227123    2 Pending Criminal Charges  SANTA CLARA CO JAIL/ELMWOOD
# 227124    2 Pending Criminal Charges        SALT LAKE COUNTY JAIL
# 227125  3 Other Immigration Violator       CLARK COUNTY DETENTION
# 227126  3 Other Immigration Violator          HAYWOOD COUNTY JAIL
# 227127    2 Pending Criminal Charges          BUNCOMBE COUNTY DR.
#
#                     Unnamed: 9  ...            Unnamed: 54  \
# 5       Detainer Facility Code  ...  Resume Custody Yes No
# 6                      BERGENJ  ...                     NO
# 7                      CHSPKVA  ...                     NO
# 8                      CHSPKVA  ...                     NO
# 9                      DWNEYCA  ...                     NO
# ...                        ...  ...                    ...
# 227123                 SCMENCA  ...                    YES
# 227124                 SLSLCUT  ...                    YES
# 227125                 CLARKAR  ...                     NO
# 227126                 HAYWDNC  ...                     NO
# 227127                 BUNCONC  ...                     NO
#
#                                           Unnamed: 55  \
# 5                                Detainer Lift Reason
# 6                               Booked into Detention
# 7                               Booked into Detention
# 8                               Booked into Detention
# 9                               Booked into Detention
# ...                                               ...
# 227123  No longer in State, Local, or Federal Custody
# 227124                                            NaN
# 227125                                            NaN
# 227126                                  Early Release
# 227127                                            NaN
#
#                       Unnamed: 56                  Unnamed: 57  \
# 5       Detainer Lift Reason Code  Active Investigation Yes No
# 6                               B                          NaN
# 7                               B                          NaN
# 8                               B                          NaN
# 9                               B                          NaN
# ...                           ...                          ...
# 227123                          G                          NaN
# 227124                        NaN                          NaN
# 227125                        NaN                          NaN
# 227126                          Z                          NaN
# 227127                        NaN                          NaN
#
#                        Unnamed: 58  \
# 5       Arrest Warrant Served Date
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# ...                            ...
# 227123                         NaN
# 227124                         NaN
# 227125                         NaN
# 227126                         NaN
# 227127                         NaN
#
#                                               Unnamed: 59  \
# 5                                           Detainer Type
# 6       I247A - Immigration Detainer - Immigration Det...
# 7       I247A - Immigration Detainer - Immigration Det...
# 8       I247A - Immigration Detainer - Immigration Det...
# 9       I247A - Immigration Detainer - Immigration Det...
# ...                                                   ...
# 227123  I247G - Request for Advance Notification of Re...
# 227124  I247G - Request for Advance Notification of Re...
# 227125  I247A - Immigration Detainer - Notice of Actio...
# 227126  I247A - Immigration Detainer - Notice of Actio...
# 227127  I247A - Immigration Detainer - Notice of Actio...
#
#                           Unnamed: 60  \
# 5       Notify Release Request Yes No
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# ...                               ...
# 227123                            NaN
# 227124                            NaN
# 227125                            NaN
# 227126                            NaN
# 227127                            NaN
#
#                                       Unnamed: 61  Unnamed: 62  \
# 5                           TOD Current Duty Site   EID DTA ID
# 6               NEWARK, NJ, DOCKET CONTROL OFFICE  b(6), b(7)c
# 7                     ERO - NORFOLK,VA Sub Office  b(6), b(7)c
# 8                     ERO - NORFOLK,VA Sub Office  b(6), b(7)c
# 9       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# ...                                           ...          ...
# 227123  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 227124  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 227125             ERO - Texarkana, AR Sub Office  b(6), b(7)c
# 227126             ERO - Henderson, NC Sub Office  b(6), b(7)c
# 227127             ERO - Henderson, NC Sub Office  b(6), b(7)c
#
#                                      Unnamed: 63
# 5                          Anonymized Identifier
# 6       0002376e90e8512b938e102d96bb78306ceba284
# 7       00025596228334361d821d68397ed1c641ab1f52
# 8       00025596228334361d821d68397ed1c641ab1f52
# 9       000256e121d033cb3fc40b2aed8829ef8014f36f
# ...                                          ...
# 227123                                       NaN
# 227124                                       NaN
# 227125                                       NaN
# 227126                                       NaN
# 227127                                       NaN
#
# [227123 rows x 64 columns]

# %%
## the first row is actually the header we want. Let's drop the header and put the actual header we want there
## create a new df, just to be safe
df2.columns = df2.iloc[0]
df2_titled = df2[1:].reset_index(drop=True)
df2_titled
# Out:
# 5      Detainer Prepare Date  Facility State  \
# 0        2025-05-08 00:00:00      NEW JERSEY
# 1        2024-10-28 00:00:00        VIRGINIA
# 2        2024-10-31 00:00:00        VIRGINIA
# 3        2024-11-03 00:00:00      CALIFORNIA
# 4        2024-11-05 00:00:00      CALIFORNIA
# ...                      ...             ...
# 227117   2025-09-30 00:00:00      CALIFORNIA
# 227118   2025-09-30 00:00:00            UTAH
# 227119   2025-02-25 00:00:00        ARKANSAS
# 227120   2025-01-25 00:00:00  NORTH CAROLINA
# 227121   2025-01-28 00:00:00  NORTH CAROLINA
#
# 5                                Facility AOR  \
# 0        New York City Area of Responsibility
# 1           Washington Area of Responsibility
# 2           Washington Area of Responsibility
# 3          Los Angeles Area of Responsibility
# 4          Los Angeles Area of Responsibility
# ...                                       ...
# 227117   San Francisco Area of Responsibility
# 227118  Salt Lake City Area of Responsibility
# 227119     New Orleans Area of Responsibility
# 227120         Atlanta Area of Responsibility
# 227121         Atlanta Area of Responsibility
#
# 5                           Port of Departure Departure Country  \
# 0                            EL PASO, TX, POE             SPAIN
# 1                                         NaN               NaN
# 2       ALEXANDRIA INTERNATIONAL AIRPORT, POE         GUATEMALA
# 3                                         NaN               NaN
# 4                                         NaN               NaN
# ...                                       ...               ...
# 227117                                    NaN               NaN
# 227118                                    NaN               NaN
# 227119                                    NaN               NaN
# 227120                                    NaN               NaN
# 227121                                    NaN               NaN
#
# 5             Departed Date                           Case Status  \
# 0       2025-09-08 00:00:00    6-Deported/Removed - Deportability
# 1                       NaN                                   NaN
# 2       2025-07-14 00:00:00  8-Excluded/Removed - Inadmissibility
# 3                       NaN                                   NaN
# 4                       NaN                                   NaN
# ...                     ...                                   ...
# 227117                  NaN                                   NaN
# 227118                  NaN                                   NaN
# 227119                  NaN                                   NaN
# 227120                  NaN                                   NaN
# 227121                  NaN                                ACTIVE
#
# 5               Detainer Criminality            Detainer Facility  \
# 0         2 Pending Criminal Charges           BERGEN COUNTY JAIL
# 1               1 Convicted Criminal         CHESAPEAKE CITY JAIL
# 2               1 Convicted Criminal         CHESAPEAKE CITY JAIL
# 3               1 Convicted Criminal          DOWNEY POLICE DEPT.
# 4         2 Pending Criminal Charges          VENTURA COUNTY JAIL
# ...                              ...                          ...
# 227117    2 Pending Criminal Charges  SANTA CLARA CO JAIL/ELMWOOD
# 227118    2 Pending Criminal Charges        SALT LAKE COUNTY JAIL
# 227119  3 Other Immigration Violator       CLARK COUNTY DETENTION
# 227120  3 Other Immigration Violator          HAYWOOD COUNTY JAIL
# 227121    2 Pending Criminal Charges          BUNCOMBE COUNTY DR.
#
# 5      Detainer Facility Code  ... Resume Custody Yes No  \
# 0                     BERGENJ  ...                    NO
# 1                     CHSPKVA  ...                    NO
# 2                     CHSPKVA  ...                    NO
# 3                     DWNEYCA  ...                    NO
# 4                     VENTUCA  ...                    NO
# ...                       ...  ...                   ...
# 227117                SCMENCA  ...                   YES
# 227118                SLSLCUT  ...                   YES
# 227119                CLARKAR  ...                    NO
# 227120                HAYWDNC  ...                    NO
# 227121                BUNCONC  ...                    NO
#
# 5                                Detainer Lift Reason  \
# 0                               Booked into Detention
# 1                               Booked into Detention
# 2                               Booked into Detention
# 3                               Booked into Detention
# 4                               Booked into Detention
# ...                                               ...
# 227117  No longer in State, Local, or Federal Custody
# 227118                                            NaN
# 227119                                            NaN
# 227120                                  Early Release
# 227121                                            NaN
#
# 5      Detainer Lift Reason Code Active Investigation Yes No  \
# 0                              B                         NaN
# 1                              B                         NaN
# 2                              B                         NaN
# 3                              B                         NaN
# 4                              B                         NaN
# ...                          ...                         ...
# 227117                         G                         NaN
# 227118                       NaN                         NaN
# 227119                       NaN                         NaN
# 227120                         Z                         NaN
# 227121                       NaN                         NaN
#
# 5      Arrest Warrant Served Date  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 227117                        NaN
# 227118                        NaN
# 227119                        NaN
# 227120                        NaN
# 227121                        NaN
#
# 5                                           Detainer Type  \
# 0       I247A - Immigration Detainer - Immigration Det...
# 1       I247A - Immigration Detainer - Immigration Det...
# 2       I247A - Immigration Detainer - Immigration Det...
# 3       I247A - Immigration Detainer - Immigration Det...
# 4       I247A - Immigration Detainer - Immigration Det...
# ...                                                   ...
# 227117  I247G - Request for Advance Notification of Re...
# 227118  I247G - Request for Advance Notification of Re...
# 227119  I247A - Immigration Detainer - Notice of Actio...
# 227120  I247A - Immigration Detainer - Notice of Actio...
# 227121  I247A - Immigration Detainer - Notice of Actio...
#
# 5      Notify Release Request Yes No  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 227117                           NaN
# 227118                           NaN
# 227119                           NaN
# 227120                           NaN
# 227121                           NaN
#
# 5                           TOD Current Duty Site   EID DTA ID  \
# 0               NEWARK, NJ, DOCKET CONTROL OFFICE  b(6), b(7)c
# 1                     ERO - NORFOLK,VA Sub Office  b(6), b(7)c
# 2                     ERO - NORFOLK,VA Sub Office  b(6), b(7)c
# 3       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 4       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# ...                                           ...          ...
# 227117  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 227118  ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 227119             ERO - Texarkana, AR Sub Office  b(6), b(7)c
# 227120             ERO - Henderson, NC Sub Office  b(6), b(7)c
# 227121             ERO - Henderson, NC Sub Office  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 0       0002376e90e8512b938e102d96bb78306ceba284
# 1       00025596228334361d821d68397ed1c641ab1f52
# 2       00025596228334361d821d68397ed1c641ab1f52
# 3       000256e121d033cb3fc40b2aed8829ef8014f36f
# 4       000256e121d033cb3fc40b2aed8829ef8014f36f
# ...                                          ...
# 227117                                       NaN
# 227118                                       NaN
# 227119                                       NaN
# 227120                                       NaN
# 227121                                       NaN
#
# [227122 rows x 64 columns]

# %%
## to be safe, let's turn the time, which is what we need, into datetime
## turn the column into datetime
df2_titled['Departed Date'] = pd.to_datetime(df2_titled['Departed Date'])

# %%
## create a subset of data for only 2022
##first: pull anything before 2023
df_2025pt2 = df2_titled[df2_titled['Departed Date'] < '2026-01-01']

# %%
##now: pull anything after 2021 from the same subset. 
df_2025pt2 = df_2025pt2[df_2025pt2['Departed Date'] > '2024-12-31']

# %%
df_2025pt2
# Out:
# 5      Detainer Prepare Date Facility State  \
# 0        2025-05-08 00:00:00     NEW JERSEY
# 2        2024-10-31 00:00:00       VIRGINIA
# 9        2025-05-27 00:00:00     NEW JERSEY
# 10       2025-05-27 00:00:00     NEW JERSEY
# 13       2024-12-09 00:00:00          TEXAS
# ...                      ...            ...
# 223860   2025-08-24 00:00:00          TEXAS
# 224003   2025-08-25 00:00:00          TEXAS
# 224016   2025-08-26 00:00:00          TEXAS
# 226990   2025-09-29 00:00:00     CALIFORNIA
# 227029   2025-09-29 00:00:00        FLORIDA
#
# 5                               Facility AOR  \
# 0       New York City Area of Responsibility
# 2          Washington Area of Responsibility
# 9              Newark Area of Responsibility
# 10             Newark Area of Responsibility
# 13            El Paso Area of Responsibility
# ...                                      ...
# 223860      Harlingen Area of Responsibility
# 224003                                   NaN
# 224016                                   NaN
# 226990      San Diego Area of Responsibility
# 227029          Miami Area of Responsibility
#
# 5                           Port of Departure Departure Country Departed Date  \
# 0                            EL PASO, TX, POE             SPAIN    2025-09-08
# 2       ALEXANDRIA INTERNATIONAL AIRPORT, POE         GUATEMALA    2025-07-14
# 9                            HOUSTON, TX, POE          HONDURAS    2025-09-19
# 10                           HOUSTON, TX, POE          HONDURAS    2025-09-19
# 13                        SAN YSIDRO, CA, POE            MEXICO    2025-09-09
# ...                                       ...               ...           ...
# 223860                       HIDALGO, TX, POE            MEXICO    2025-08-25
# 224003             HOUSTON, TX (AIRPORT), POE         GUATEMALA    2025-12-20
# 224016             HOUSTON, TX (AIRPORT), POE         GUATEMALA    2025-11-08
# 226990                    SAN YSIDRO, CA, POE            MEXICO    2025-12-13
# 227029                     HARLINGEN, TX, POE            MEXICO    2025-10-09
#
# 5                                Case Status          Detainer Criminality  \
# 0         6-Deported/Removed - Deportability    2 Pending Criminal Charges
# 2       8-Excluded/Removed - Inadmissibility          1 Convicted Criminal
# 9       8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 10      8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 13      8-Excluded/Removed - Inadmissibility  3 Other Immigration Violator
# ...                                      ...                           ...
# 223860                        9-VR Witnessed  3 Other Immigration Violator
# 224003  8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 224016  8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 226990           8-Excluded/Deported/Removed  3 Other Immigration Violator
# 227029       3-Voluntary Departure Confirmed    2 Pending Criminal Charges
#
# 5                   Detainer Facility Detainer Facility Code  ...  \
# 0                  BERGEN COUNTY JAIL                BERGENJ  ...
# 2                CHESAPEAKE CITY JAIL                CHSPKVA  ...
# 9                   OCEAN COUNTY JAIL                OCEANNJ  ...
# 10                  OCEAN COUNTY JAIL                OCEANNJ  ...
# 13           EL PASO COUNTY JAIL (TX)                ELPCOTX  ...
# ...                               ...                    ...  ...
# 223860  HIDALGO COUNTY SHERIFF'S JAIL                HIDALTX  ...
# 224003             HARRIS COUNTY JAIL                HARISTX  ...
# 224016             HARRIS COUNTY JAIL                HARISTX  ...
# 226990          SAN DIEGO COUNTY JAIL                SNDCOCA  ...
# 227029               POLK COUNTY JAIL                POLKJFL  ...
#
# 5      Resume Custody Yes No      Detainer Lift Reason  \
# 0                         NO     Booked into Detention
# 2                         NO     Booked into Detention
# 9                        YES     Booked into Detention
# 10                        NO     Booked into Detention
# 13                        NO     Booked into Detention
# ...                      ...                       ...
# 223860                    NO     Booked into Detention
# 224003                    NO     Booked into Detention
# 224016                    NO     Booked into Detention
# 226990                    NO  Detainer Declined by LEA
# 227029                    NO     Booked into Detention
#
# 5      Detainer Lift Reason Code Active Investigation Yes No  \
# 0                              B                         NaN
# 2                              B                         NaN
# 9                              B                         NaN
# 10                             B                         NaN
# 13                             B                         NaN
# ...                          ...                         ...
# 223860                         B                         NaN
# 224003                         B                         NaN
# 224016                         B                         NaN
# 226990                         A                         NaN
# 227029                         B                         NaN
#
# 5      Arrest Warrant Served Date  \
# 0                             NaN
# 2                             NaN
# 9                             NaN
# 10                            NaN
# 13                            NaN
# ...                           ...
# 223860                        NaN
# 224003                        NaN
# 224016                        NaN
# 226990                        NaN
# 227029                        NaN
#
# 5                                           Detainer Type  \
# 0       I247A - Immigration Detainer - Immigration Det...
# 2       I247A - Immigration Detainer - Immigration Det...
# 9       I247G - Request for Advance Notification of Re...
# 10      I247A - Immigration Detainer - Notice of Actio...
# 13      I247A - Immigration Detainer - Immigration Det...
# ...                                                   ...
# 223860  I247A - Immigration Detainer - Notice of Actio...
# 224003  I247A - Immigration Detainer - Notice of Actio...
# 224016  I247A - Immigration Detainer - Notice of Actio...
# 226990  I247A - Immigration Detainer - Notice of Actio...
# 227029  I247A - Immigration Detainer - Notice of Actio...
#
# 5      Notify Release Request Yes No  \
# 0                                NaN
# 2                                NaN
# 9                                NaN
# 10                               NaN
# 13                               NaN
# ...                              ...
# 223860                           NaN
# 224003                           NaN
# 224016                           NaN
# 226990                           NaN
# 227029                           NaN
#
# 5                           TOD Current Duty Site   EID DTA ID  \
# 0               NEWARK, NJ, DOCKET CONTROL OFFICE  b(6), b(7)c
# 2                     ERO - NORFOLK,VA Sub Office  b(6), b(7)c
# 9       ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 10              ICE ERO - MOUNT LAUREL NJ SUB-OFC  b(6), b(7)c
# 13           ERO - Otero County Processing Center  b(6), b(7)c
# ...                                           ...          ...
# 223860             ERO - EDINBURG, TX, SUB-OFFICE  b(6), b(7)c
# 224003     ERO - Montgomery County, TX Sub Office  b(6), b(7)c
# 224016     ERO - Montgomery County, TX Sub Office  b(6), b(7)c
# 226990              ERO - Imperial, CA Sub Office  b(6), b(7)c
# 227029    KROME, MIAMI, FL, DOCKET CONTROL OFFICE  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 0       0002376e90e8512b938e102d96bb78306ceba284
# 2       00025596228334361d821d68397ed1c641ab1f52
# 9       00035ca115ef0bcaa06937b5e612ae114f1076e6
# 10      00035ca115ef0bcaa06937b5e612ae114f1076e6
# 13      00046a7b75893dc7f4e084fde3d4e0d4aab014d5
# ...                                          ...
# 223860                                       NaN
# 224003                                       NaN
# 224016                                       NaN
# 226990                                       NaN
# 227029                                       NaN
#
# [69803 rows x 64 columns]

# %%
##Let us do Extraction 1: 2022 ICE Detainers data
df_2025pt2.to_csv('FilteredData/2025ICEDetainersData2.csv', index=False)

# %%
## let's pull data that i have downloaded. starting with the first file
df3 = pd.read_excel('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICE Arrests/CLEANED-ICEarrests-Albany/TEST2/RawData/Detainers/2026-ICLI-00005_Detainers_FY26_20260311_Redacted.xlsx')
df3
# Out:
#                        ERO LESA Statistical Tracking Unit  Unnamed: 1  \
# 0             For Official Use Only (FOUO)/Pre-decisional         NaN
# 1       Deportation Data Project - 2026-ICLI-00005 – 0...         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4       ERO Detainers Prepared FY2026YTD (10/01/2025 -...         NaN
# ...                                                   ...         ...
# 112840                                2026-03-11 00:00:00     FLORIDA
# 112841                                2026-03-10 00:00:00       TEXAS
# 112842                                2026-03-11 00:00:00     GEORGIA
# 112843                                2026-03-10 00:00:00     GEORGIA
# 112844                                2026-03-10 00:00:00  CALIFORNIA
#
#                                 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                      NaN        NaN        NaN        NaN
# 1                                      NaN        NaN        NaN        NaN
# 2                                      NaN        NaN        NaN        NaN
# 3                                      NaN        NaN        NaN        NaN
# 4                                      NaN        NaN        NaN        NaN
# ...                                    ...        ...        ...        ...
# 112840        Miami Area of Responsibility        NaN        NaN        NaN
# 112841       Dallas Area of Responsibility        NaN        NaN        NaN
# 112842      Atlanta Area of Responsibility        NaN        NaN        NaN
# 112843      Atlanta Area of Responsibility        NaN        NaN        NaN
# 112844  Los Angeles Area of Responsibility        NaN        NaN        NaN
#
#        Unnamed: 6                    Unnamed: 7  \
# 0             NaN                           NaN
# 1             NaN                           NaN
# 2             NaN                           NaN
# 3             NaN                           NaN
# 4             NaN                           NaN
# ...           ...                           ...
# 112840        NaN    2 Pending Criminal Charges
# 112841        NaN    2 Pending Criminal Charges
# 112842        NaN    2 Pending Criminal Charges
# 112843        NaN  3 Other Immigration Violator
# 112844        NaN  3 Other Immigration Violator
#
#                                 Unnamed: 8 Unnamed: 9  ... Unnamed: 54  \
# 0                                      NaN        NaN  ...         NaN
# 1                                      NaN        NaN  ...         NaN
# 2                                      NaN        NaN  ...         NaN
# 3                                      NaN        NaN  ...         NaN
# 4                                      NaN        NaN  ...         NaN
# ...                                    ...        ...  ...         ...
# 112840               ST. LUCIE COUNTY JAIL    STLUCFL  ...          NO
# 112841        ELLIS COUNTY SHERIFF'S DEPT.    ELLISTX  ...          NO
# 112842  COBB CO SHERIFFS OFC ADULT DET CTR    COBBJGA  ...          NO
# 112843               COWETA COUNTY SHERIFF    CWETAGA  ...          NO
# 112844                  ORANGE COUNTY JAIL    ORANGCA  ...         YES
#
#        Unnamed: 55 Unnamed: 56 Unnamed: 57 Unnamed: 58  \
# 0              NaN         NaN         NaN         NaN
# 1              NaN         NaN         NaN         NaN
# 2              NaN         NaN         NaN         NaN
# 3              NaN         NaN         NaN         NaN
# 4              NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...
# 112840         NaN         NaN         NaN         NaN
# 112841         NaN         NaN         NaN         NaN
# 112842         NaN         NaN         NaN         NaN
# 112843         NaN         NaN         NaN         NaN
# 112844         NaN         NaN         NaN         NaN
#
#                                               Unnamed: 59 Unnamed: 60  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 112840  I247A - Immigration Detainer - Notice of Actio...         NaN
# 112841  I247A - Immigration Detainer - Notice of Actio...         NaN
# 112842  I247A - Immigration Detainer - Notice of Actio...         NaN
# 112843  I247A - Immigration Detainer - Notice of Actio...         NaN
# 112844  I247G - Request for Advance Notification of Re...         NaN
#
#                                       Unnamed: 61  Unnamed: 62 Unnamed: 63
# 0                                             NaN          NaN         NaN
# 1                                             NaN          NaN         NaN
# 2                                             NaN          NaN         NaN
# 3                                             NaN          NaN         NaN
# 4                                             NaN          NaN         NaN
# ...                                           ...          ...         ...
# 112840    KROME, MIAMI, FL, DOCKET CONTROL OFFICE  b(6), b(7)c         NaN
# 112841          DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c         NaN
# 112842         ATLANTA, GA, DOCKET CONTROL OFFICE  b(6), b(7)c         NaN
# 112843         ATLANTA, GA, DOCKET CONTROL OFFICE  b(6), b(7)c         NaN
# 112844  ERO - Pacific Enforcement Response Center  b(6), b(7)c         NaN
#
# [112845 rows x 64 columns]

# %%
#### As you can see: we don't need the first couple rows, it has unneeded rows. Let's remove the rows
df3 = df3.iloc[5:]
df3
# Out:
#        ERO LESA Statistical Tracking Unit      Unnamed: 1  \
# 5                   Detainer Prepare Date  Facility State
# 6                     2025-10-27 00:00:00          OREGON
# 7                     2025-10-30 00:00:00            UTAH
# 8                     2026-02-14 00:00:00         FLORIDA
# 9                     2026-02-12 00:00:00  NORTH CAROLINA
# ...                                   ...             ...
# 112840                2026-03-11 00:00:00         FLORIDA
# 112841                2026-03-10 00:00:00           TEXAS
# 112842                2026-03-11 00:00:00         GEORGIA
# 112843                2026-03-10 00:00:00         GEORGIA
# 112844                2026-03-10 00:00:00      CALIFORNIA
#
#                                 Unnamed: 2         Unnamed: 3  \
# 5                             Facility AOR  Port of Departure
# 6           Seattle Area of Responsibility                NaN
# 7                                      NaN   NOGALES, AZ, POE
# 8             Miami Area of Responsibility                NaN
# 9           Atlanta Area of Responsibility                NaN
# ...                                    ...                ...
# 112840        Miami Area of Responsibility                NaN
# 112841       Dallas Area of Responsibility                NaN
# 112842      Atlanta Area of Responsibility                NaN
# 112843      Atlanta Area of Responsibility                NaN
# 112844  Los Angeles Area of Responsibility                NaN
#
#                Unnamed: 4           Unnamed: 5  \
# 5       Departure Country        Departed Date
# 6                     NaN                  NaN
# 7                  MEXICO  2025-12-20 00:00:00
# 8                     NaN                  NaN
# 9                     NaN                  NaN
# ...                   ...                  ...
# 112840                NaN                  NaN
# 112841                NaN                  NaN
# 112842                NaN                  NaN
# 112843                NaN                  NaN
# 112844                NaN                  NaN
#
#                                   Unnamed: 6                    Unnamed: 7  \
# 5                                Case Status          Detainer Criminality
# 6                                     ACTIVE          1 Convicted Criminal
# 7       8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 8                                     ACTIVE    2 Pending Criminal Charges
# 9                                        NaN          1 Convicted Criminal
# ...                                      ...                           ...
# 112840                                   NaN    2 Pending Criminal Charges
# 112841                                   NaN    2 Pending Criminal Charges
# 112842                                   NaN    2 Pending Criminal Charges
# 112843                                   NaN  3 Other Immigration Violator
# 112844                                   NaN  3 Other Immigration Violator
#
#                                 Unnamed: 8              Unnamed: 9  ...  \
# 5                        Detainer Facility  Detainer Facility Code  ...
# 6                  SHERIDAN FED.CORR.INST.                  BOPSHE  ...
# 7                       US MARSHALS - UTAH                   USMUT  ...
# 8                          LEE COUNTY JAIL                 LEECOFL  ...
# 9          MECKLENBURG COUNTY JAIL CENTRAL                 MECKLN2  ...
# ...                                    ...                     ...  ...
# 112840               ST. LUCIE COUNTY JAIL                 STLUCFL  ...
# 112841        ELLIS COUNTY SHERIFF'S DEPT.                 ELLISTX  ...
# 112842  COBB CO SHERIFFS OFC ADULT DET CTR                 COBBJGA  ...
# 112843               COWETA COUNTY SHERIFF                 CWETAGA  ...
# 112844                  ORANGE COUNTY JAIL                 ORANGCA  ...
#
#                   Unnamed: 54                                 Unnamed: 55  \
# 5       Resume Custody Yes No                        Detainer Lift Reason
# 6                          NO                                         NaN
# 7                          NO                       Booked into Detention
# 8                          NO                       Booked into Detention
# 9                          NO  USC or Presumptive Claim to US Citizenship
# ...                       ...                                         ...
# 112840                     NO                                         NaN
# 112841                     NO                                         NaN
# 112842                     NO                                         NaN
# 112843                     NO                                         NaN
# 112844                    YES                                         NaN
#
#                       Unnamed: 56                  Unnamed: 57  \
# 5       Detainer Lift Reason Code  Active Investigation Yes No
# 6                             NaN                          NaN
# 7                               B                          NaN
# 8                               B                          NaN
# 9                               X                          NaN
# ...                           ...                          ...
# 112840                        NaN                          NaN
# 112841                        NaN                          NaN
# 112842                        NaN                          NaN
# 112843                        NaN                          NaN
# 112844                        NaN                          NaN
#
#                        Unnamed: 58  \
# 5       Arrest Warrant Served Date
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# ...                            ...
# 112840                         NaN
# 112841                         NaN
# 112842                         NaN
# 112843                         NaN
# 112844                         NaN
#
#                                               Unnamed: 59  \
# 5                                           Detainer Type
# 6       I247A - Immigration Detainer - Notice of Actio...
# 7       I247A - Immigration Detainer - Notice of Actio...
# 8       I247A - Immigration Detainer - Notice of Actio...
# 9       I247A - Immigration Detainer - Notice of Actio...
# ...                                                   ...
# 112840  I247A - Immigration Detainer - Notice of Actio...
# 112841  I247A - Immigration Detainer - Notice of Actio...
# 112842  I247A - Immigration Detainer - Notice of Actio...
# 112843  I247A - Immigration Detainer - Notice of Actio...
# 112844  I247G - Request for Advance Notification of Re...
#
#                           Unnamed: 60  \
# 5       Notify Release Request Yes No
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# ...                               ...
# 112840                            NaN
# 112841                            NaN
# 112842                            NaN
# 112843                            NaN
# 112844                            NaN
#
#                                       Unnamed: 61  Unnamed: 62  \
# 5                           TOD Current Duty Site   EID DTA ID
# 6             PORTLAND, OR, DOCKET CONTROL OFFICE  b(6), b(7)c
# 7       SALT LAKE CITY, UT, DOCKET CONTROL OFFICE  b(6), b(7)c
# 8                                             NaN  b(6), b(7)c
# 9                  ERO - Charlotte, NC Sub-Office  b(6), b(7)c
# ...                                           ...          ...
# 112840    KROME, MIAMI, FL, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112841          DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112842         ATLANTA, GA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112843         ATLANTA, GA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112844  ERO - Pacific Enforcement Response Center  b(6), b(7)c
#
#                                      Unnamed: 63
# 5                          Anonymized Identifier
# 6       0000eccad0ce73c253ff57e650ecdcee278bf1fd
# 7       000123c8701799c3f1c69fc5b9237441afcf6161
# 8       0001c9598ba1c9866270b617f4c82ff2e04d3e29
# 9       0003948dedafe23c39ce1dfcf700910354327e62
# ...                                          ...
# 112840                                       NaN
# 112841                                       NaN
# 112842                                       NaN
# 112843                                       NaN
# 112844                                       NaN
#
# [112840 rows x 64 columns]

# %%
## the first row is actually the header we want. Let's drop the header and put the actual header we want there
## create a new df, just to be safe
df3.columns = df3.iloc[0]
df3_titled = df3[1:].reset_index(drop=True)
df3_titled
# Out:
# 5      Detainer Prepare Date  Facility State  \
# 0        2025-10-27 00:00:00          OREGON
# 1        2025-10-30 00:00:00            UTAH
# 2        2026-02-14 00:00:00         FLORIDA
# 3        2026-02-12 00:00:00  NORTH CAROLINA
# 4        2025-10-28 00:00:00           TEXAS
# ...                      ...             ...
# 112834   2026-03-11 00:00:00         FLORIDA
# 112835   2026-03-10 00:00:00           TEXAS
# 112836   2026-03-11 00:00:00         GEORGIA
# 112837   2026-03-10 00:00:00         GEORGIA
# 112838   2026-03-10 00:00:00      CALIFORNIA
#
# 5                             Facility AOR Port of Departure  \
# 0           Seattle Area of Responsibility               NaN
# 1                                      NaN  NOGALES, AZ, POE
# 2             Miami Area of Responsibility               NaN
# 3           Atlanta Area of Responsibility               NaN
# 4                                      NaN  HIDALGO, TX, POE
# ...                                    ...               ...
# 112834        Miami Area of Responsibility               NaN
# 112835       Dallas Area of Responsibility               NaN
# 112836      Atlanta Area of Responsibility               NaN
# 112837      Atlanta Area of Responsibility               NaN
# 112838  Los Angeles Area of Responsibility               NaN
#
# 5      Departure Country        Departed Date  \
# 0                    NaN                  NaN
# 1                 MEXICO  2025-12-20 00:00:00
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                 MEXICO  2025-11-05 00:00:00
# ...                  ...                  ...
# 112834               NaN                  NaN
# 112835               NaN                  NaN
# 112836               NaN                  NaN
# 112837               NaN                  NaN
# 112838               NaN                  NaN
#
# 5                                Case Status          Detainer Criminality  \
# 0                                     ACTIVE          1 Convicted Criminal
# 1       8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 2                                     ACTIVE    2 Pending Criminal Charges
# 3                                        NaN          1 Convicted Criminal
# 4         6-Deported/Removed - Deportability  3 Other Immigration Violator
# ...                                      ...                           ...
# 112834                                   NaN    2 Pending Criminal Charges
# 112835                                   NaN    2 Pending Criminal Charges
# 112836                                   NaN    2 Pending Criminal Charges
# 112837                                   NaN  3 Other Immigration Violator
# 112838                                   NaN  3 Other Immigration Violator
#
# 5                        Detainer Facility Detainer Facility Code  ...  \
# 0                  SHERIDAN FED.CORR.INST.                 BOPSHE  ...
# 1                       US MARSHALS - UTAH                  USMUT  ...
# 2                          LEE COUNTY JAIL                LEECOFL  ...
# 3          MECKLENBURG COUNTY JAIL CENTRAL                MECKLN2  ...
# 4                 GALVESTON COUNTY SHERIFF                GALVETX  ...
# ...                                    ...                    ...  ...
# 112834               ST. LUCIE COUNTY JAIL                STLUCFL  ...
# 112835        ELLIS COUNTY SHERIFF'S DEPT.                ELLISTX  ...
# 112836  COBB CO SHERIFFS OFC ADULT DET CTR                COBBJGA  ...
# 112837               COWETA COUNTY SHERIFF                CWETAGA  ...
# 112838                  ORANGE COUNTY JAIL                ORANGCA  ...
#
# 5      Resume Custody Yes No                        Detainer Lift Reason  \
# 0                         NO                                         NaN
# 1                         NO                       Booked into Detention
# 2                         NO                       Booked into Detention
# 3                         NO  USC or Presumptive Claim to US Citizenship
# 4                         NO                       Booked into Detention
# ...                      ...                                         ...
# 112834                    NO                                         NaN
# 112835                    NO                                         NaN
# 112836                    NO                                         NaN
# 112837                    NO                                         NaN
# 112838                   YES                                         NaN
#
# 5      Detainer Lift Reason Code Active Investigation Yes No  \
# 0                            NaN                         NaN
# 1                              B                         NaN
# 2                              B                         NaN
# 3                              X                         NaN
# 4                              B                         NaN
# ...                          ...                         ...
# 112834                       NaN                         NaN
# 112835                       NaN                         NaN
# 112836                       NaN                         NaN
# 112837                       NaN                         NaN
# 112838                       NaN                         NaN
#
# 5      Arrest Warrant Served Date  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 112834                        NaN
# 112835                        NaN
# 112836                        NaN
# 112837                        NaN
# 112838                        NaN
#
# 5                                           Detainer Type  \
# 0       I247A - Immigration Detainer - Notice of Actio...
# 1       I247A - Immigration Detainer - Notice of Actio...
# 2       I247A - Immigration Detainer - Notice of Actio...
# 3       I247A - Immigration Detainer - Notice of Actio...
# 4       I247A - Immigration Detainer - Notice of Actio...
# ...                                                   ...
# 112834  I247A - Immigration Detainer - Notice of Actio...
# 112835  I247A - Immigration Detainer - Notice of Actio...
# 112836  I247A - Immigration Detainer - Notice of Actio...
# 112837  I247A - Immigration Detainer - Notice of Actio...
# 112838  I247G - Request for Advance Notification of Re...
#
# 5      Notify Release Request Yes No  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 112834                           NaN
# 112835                           NaN
# 112836                           NaN
# 112837                           NaN
# 112838                           NaN
#
# 5                           TOD Current Duty Site   EID DTA ID  \
# 0             PORTLAND, OR, DOCKET CONTROL OFFICE  b(6), b(7)c
# 1       SALT LAKE CITY, UT, DOCKET CONTROL OFFICE  b(6), b(7)c
# 2                                             NaN  b(6), b(7)c
# 3                  ERO - Charlotte, NC Sub-Office  b(6), b(7)c
# 4              HOUSTON, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# ...                                           ...          ...
# 112834    KROME, MIAMI, FL, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112835          DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112836         ATLANTA, GA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112837         ATLANTA, GA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 112838  ERO - Pacific Enforcement Response Center  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 0       0000eccad0ce73c253ff57e650ecdcee278bf1fd
# 1       000123c8701799c3f1c69fc5b9237441afcf6161
# 2       0001c9598ba1c9866270b617f4c82ff2e04d3e29
# 3       0003948dedafe23c39ce1dfcf700910354327e62
# 4       0006023d014d189c1b0dd2ff30a1c27b3b31892b
# ...                                          ...
# 112834                                       NaN
# 112835                                       NaN
# 112836                                       NaN
# 112837                                       NaN
# 112838                                       NaN
#
# [112839 rows x 64 columns]

# %%
## to be safe, let's turn the time, which is what we need, into datetime
## turn the column into datetime
df3_titled['Departed Date'] = pd.to_datetime(df3_titled['Departed Date'])

# %%
## create a subset of data
##first: pull anything
df_2025pt3 = df3_titled[df3_titled['Departed Date'] < '2026-01-01']

# %%
##now: pull anything after 2024 from the same subset. 
df_2025pt3 = df_2025pt3[df_2025pt3['Departed Date'] > '2024-12-31']

# %%
df_2025pt3
# Out:
# 5      Detainer Prepare Date Facility State  \
# 1        2025-10-30 00:00:00           UTAH
# 4        2025-10-28 00:00:00          TEXAS
# 27       2025-11-20 00:00:00        FLORIDA
# 29       2025-12-05 00:00:00       VIRGINIA
# 40       2025-10-02 00:00:00    PUERTO RICO
# ...                      ...            ...
# 96824    2025-11-02 00:00:00          TEXAS
# 96834    2025-12-01 00:00:00     CALIFORNIA
# 98216    2025-10-15 00:00:00          TEXAS
# 101881   2025-11-22 00:00:00          TEXAS
# 103624   2025-12-12 00:00:00          TEXAS
#
# 5                             Facility AOR  \
# 1                                      NaN
# 4                                      NaN
# 27            Miami Area of Responsibility
# 29       Washington Area of Responsibility
# 40            Miami Area of Responsibility
# ...                                    ...
# 96824        Dallas Area of Responsibility
# 96834   Los Angeles Area of Responsibility
# 98216                                  NaN
# 101881    Harlingen Area of Responsibility
# 103624    Harlingen Area of Responsibility
#
# 5                           Port of Departure   Departure Country  \
# 1                            NOGALES, AZ, POE              MEXICO
# 4                            HIDALGO, TX, POE              MEXICO
# 27                           PHOENIX, AZ, POE           VENEZUELA
# 29      ALEXANDRIA INTERNATIONAL AIRPORT, POE           GUATEMALA
# 40             Luis Munoz Marin Int'l Airport  DOMINICAN REPUBLIC
# ...                                       ...                 ...
# 96824                         DALLAS, TX, POE            HONDURAS
# 96834                     SAN YSIDRO, CA, POE              MEXICO
# 98216   ALEXANDRIA INTERNATIONAL AIRPORT, POE            COLOMBIA
# 101881                        LAREDO, TX, POE              MEXICO
# 103624                        LAREDO, TX, POE              MEXICO
#
# 5      Departed Date                           Case Status  \
# 1         2025-12-20  8-Excluded/Removed - Inadmissibility
# 4         2025-11-05    6-Deported/Removed - Deportability
# 27        2025-12-03       3-Voluntary Departure Confirmed
# 29        2025-12-12       3-Voluntary Departure Confirmed
# 40        2025-11-03  8-Excluded/Removed - Inadmissibility
# ...              ...                                   ...
# 96824     2025-12-17       3-Voluntary Departure Confirmed
# 96834     2025-12-23  8-Excluded/Removed - Inadmissibility
# 98216     2025-11-28       3-Voluntary Departure Confirmed
# 101881    2025-11-25                        9-VR Witnessed
# 103624    2025-12-15                        9-VR Witnessed
#
# 5               Detainer Criminality               Detainer Facility  \
# 1         2 Pending Criminal Charges              US MARSHALS - UTAH
# 4       3 Other Immigration Violator        GALVESTON COUNTY SHERIFF
# 27        2 Pending Criminal Charges        HILLSBOROUGH COUNTY JAIL
# 29        2 Pending Criminal Charges  CULPEPER CO. ADULT DET. CENTER
# 40        2 Pending Criminal Charges          BAYAMON REGIONAL JAIL.
# ...                              ...                             ...
# 96824     2 Pending Criminal Charges         GRAND PRAIRIE CITY JAIL
# 96834           1 Convicted Criminal        LOS ANGELES MET.DET.CTR.
# 98216     2 Pending Criminal Charges              HARRIS COUNTY JAIL
# 101881    2 Pending Criminal Charges                WEBB COUNTY JAIL
# 103624    2 Pending Criminal Charges                WEBB COUNTY JAIL
#
# 5      Detainer Facility Code  ... Resume Custody Yes No  \
# 1                       USMUT  ...                    NO
# 4                     GALVETX  ...                    NO
# 27                    HICOJFL  ...                    NO
# 29                    CULPEVA  ...                    NO
# 40                    PRBAYAM  ...                    NO
# ...                       ...  ...                   ...
# 96824                 GRPRATX  ...                    NO
# 96834                  BOPLOS  ...                    NO
# 98216                 HARISTX  ...                    NO
# 101881                WEBCOTX  ...                    NO
# 103624                WEBCOTX  ...                    NO
#
# 5        Detainer Lift Reason Detainer Lift Reason Code  \
# 1       Booked into Detention                         B
# 4       Booked into Detention                         B
# 27      Booked into Detention                         B
# 29      Booked into Detention                         B
# 40      Booked into Detention                         B
# ...                       ...                       ...
# 96824   Booked into Detention                         B
# 96834   Booked into Detention                         B
# 98216   Booked into Detention                         B
# 101881            Case Closed                         C
# 103624  Booked into Detention                         B
#
# 5      Active Investigation Yes No Arrest Warrant Served Date  \
# 1                              NaN                        NaN
# 4                              NaN                        NaN
# 27                             NaN                        NaN
# 29                             NaN                        NaN
# 40                             NaN                        NaN
# ...                            ...                        ...
# 96824                          NaN                        NaN
# 96834                          NaN                        NaN
# 98216                          NaN                        NaN
# 101881                         NaN                        NaN
# 103624                         NaN                        NaN
#
# 5                                           Detainer Type  \
# 1       I247A - Immigration Detainer - Notice of Actio...
# 4       I247A - Immigration Detainer - Notice of Actio...
# 27      I247A - Immigration Detainer - Notice of Actio...
# 29      I247A - Immigration Detainer - Notice of Actio...
# 40      I247A - Immigration Detainer - Notice of Actio...
# ...                                                   ...
# 96824   I247A - Immigration Detainer - Notice of Actio...
# 96834   I247A - Immigration Detainer - Notice of Actio...
# 98216   I247A - Immigration Detainer - Notice of Actio...
# 101881  I247A - Immigration Detainer - Notice of Actio...
# 103624  I247A - Immigration Detainer - Notice of Actio...
#
# 5      Notify Release Request Yes No  \
# 1                                NaN
# 4                                NaN
# 27                               NaN
# 29                               NaN
# 40                               NaN
# ...                              ...
# 96824                            NaN
# 96834                            NaN
# 98216                            NaN
# 101881                           NaN
# 103624                           NaN
#
# 5                                   TOD Current Duty Site   EID DTA ID  \
# 1               SALT LAKE CITY, UT, DOCKET CONTROL OFFICE  b(6), b(7)c
# 4                      HOUSTON, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 27                       TAMPA, FL, DOCKET CONTROL OFFICE  b(6), b(7)c
# 29                      ERO - Harrisonburg, VA Sub Office  b(6), b(7)c
# 40      SAN JUAN, PR, SERVICE PROCESSING CENTER (DOCKE...  b(6), b(7)c
# ...                                                   ...          ...
# 96824                   DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 96834              LOS ANGELES, CA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 98216              ERO - Montgomery County, TX Sub Office  b(6), b(7)c
# 101881               HARLINGEN, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 103624                  ERO - Laredo, TX Detention Center  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 1       000123c8701799c3f1c69fc5b9237441afcf6161
# 4       0006023d014d189c1b0dd2ff30a1c27b3b31892b
# 27      00116109bb3123818f040adddce95629116a1379
# 29      0011a60eb13c05f1a107c9ba6eeac91296d3e263
# 40      001b481adfd9620344058c6b0a6d7c91f301eb69
# ...                                          ...
# 96824   fff6a919573b3801f4824bfed092235e32c4f9d7
# 96834   fffb1d13fc1ac1fffd53bfcf81c6d66305e4863b
# 98216                                        NaN
# 101881                                       NaN
# 103624                                       NaN
#
# [10067 rows x 64 columns]

# %%
df_2025pt3.to_csv('FilteredData/2025ICEDetainersData3.csv', index=False)

# %%
pdList = [df_2025pt1, df_2025pt2, df_2025pt3]
df_All2025 = pd.concat(pdList)
df_All2025
# Out:
# 5      Detainer Prepare Date Facility State  \
# 28       2024-07-08 00:00:00       ARKANSAS
# 35       2024-01-28 00:00:00       VIRGINIA
# 40       2024-03-27 00:00:00          TEXAS
# 46       2024-06-10 00:00:00        ARIZONA
# 47       2024-08-12 00:00:00        ARIZONA
# ...                      ...            ...
# 96824    2025-11-02 00:00:00          TEXAS
# 96834    2025-12-01 00:00:00     CALIFORNIA
# 98216    2025-10-15 00:00:00          TEXAS
# 101881   2025-11-22 00:00:00          TEXAS
# 103624   2025-12-12 00:00:00          TEXAS
#
# 5                             Facility AOR  \
# 28      New Orleans Area of Responsibility
# 35       Washington Area of Responsibility
# 40           Dallas Area of Responsibility
# 46          Phoenix Area of Responsibility
# 47          Phoenix Area of Responsibility
# ...                                    ...
# 96824        Dallas Area of Responsibility
# 96834   Los Angeles Area of Responsibility
# 98216                                  NaN
# 101881    Harlingen Area of Responsibility
# 103624    Harlingen Area of Responsibility
#
# 5                           Port of Departure Departure Country Departed Date  \
# 28      ALEXANDRIA INTERNATIONAL AIRPORT, POE         GUATEMALA    2025-04-01
# 35      ALEXANDRIA INTERNATIONAL AIRPORT, POE         GUATEMALA    2025-02-26
# 40      ALEXANDRIA INTERNATIONAL AIRPORT, POE       EL SALVADOR    2025-10-07
# 46                           NOGALES, AZ, POE            MEXICO    2025-01-08
# 47                           NOGALES, AZ, POE            MEXICO    2025-01-08
# ...                                       ...               ...           ...
# 96824                         DALLAS, TX, POE          HONDURAS    2025-12-17
# 96834                     SAN YSIDRO, CA, POE            MEXICO    2025-12-23
# 98216   ALEXANDRIA INTERNATIONAL AIRPORT, POE          COLOMBIA    2025-11-28
# 101881                        LAREDO, TX, POE            MEXICO    2025-11-25
# 103624                        LAREDO, TX, POE            MEXICO    2025-12-15
#
# 5                                Case Status          Detainer Criminality  \
# 28      8-Excluded/Removed - Inadmissibility  3 Other Immigration Violator
# 35        6-Deported/Removed - Deportability          1 Convicted Criminal
# 40      8-Excluded/Removed - Inadmissibility    2 Pending Criminal Charges
# 46      8-Excluded/Removed - Inadmissibility          1 Convicted Criminal
# 47      8-Excluded/Removed - Inadmissibility          1 Convicted Criminal
# ...                                      ...                           ...
# 96824        3-Voluntary Departure Confirmed    2 Pending Criminal Charges
# 96834   8-Excluded/Removed - Inadmissibility          1 Convicted Criminal
# 98216        3-Voluntary Departure Confirmed    2 Pending Criminal Charges
# 101881                        9-VR Witnessed    2 Pending Criminal Charges
# 103624                        9-VR Witnessed    2 Pending Criminal Charges
#
# 5                 Detainer Facility Detainer Facility Code  ...  \
# 28      PULASKI COUNTY REG.DET.FAC.                PULASAR  ...
# 35                   PRINCE WILLIAM                PWILLVA  ...
# 40              IRVING POLICE DEPT.                IRVNGTX  ...
# 46             MARICOPA COUNTY JAIL                MCFAJAZ  ...
# 47             US MARSHAL - PHOENIX                 USMPHO  ...
# ...                             ...                    ...  ...
# 96824       GRAND PRAIRIE CITY JAIL                GRPRATX  ...
# 96834      LOS ANGELES MET.DET.CTR.                 BOPLOS  ...
# 98216            HARRIS COUNTY JAIL                HARISTX  ...
# 101881             WEBB COUNTY JAIL                WEBCOTX  ...
# 103624             WEBB COUNTY JAIL                WEBCOTX  ...
#
# 5      Resume Custody Yes No      Detainer Lift Reason  \
# 28                        NO     Booked into Detention
# 35                        NO  Detainer Declined by LEA
# 40                        NO     Booked into Detention
# 46                        NO     Booked into Detention
# 47                        NO     Booked into Detention
# ...                      ...                       ...
# 96824                     NO     Booked into Detention
# 96834                     NO     Booked into Detention
# 98216                     NO     Booked into Detention
# 101881                    NO               Case Closed
# 103624                    NO     Booked into Detention
#
# 5      Detainer Lift Reason Code Active Investigation Yes No  \
# 28                             B                         NaN
# 35                             A                         NaN
# 40                             B                         NaN
# 46                             B                         NaN
# 47                             B                         NaN
# ...                          ...                         ...
# 96824                          B                         NaN
# 96834                          B                         NaN
# 98216                          B                         NaN
# 101881                         C                         NaN
# 103624                         B                         NaN
#
# 5      Arrest Warrant Served Date  \
# 28                            NaN
# 35                            NaN
# 40                            NaN
# 46                            NaN
# 47                            NaN
# ...                           ...
# 96824                         NaN
# 96834                         NaN
# 98216                         NaN
# 101881                        NaN
# 103624                        NaN
#
# 5                                           Detainer Type  \
# 28      I247A - Immigration Detainer - Immigration Det...
# 35      I247A - Immigration Detainer - Immigration Det...
# 40      I247A - Immigration Detainer - Immigration Det...
# 46      I247A - Immigration Detainer - Immigration Det...
# 47      I247A - Immigration Detainer - Immigration Det...
# ...                                                   ...
# 96824   I247A - Immigration Detainer - Notice of Actio...
# 96834   I247A - Immigration Detainer - Notice of Actio...
# 98216   I247A - Immigration Detainer - Notice of Actio...
# 101881  I247A - Immigration Detainer - Notice of Actio...
# 103624  I247A - Immigration Detainer - Notice of Actio...
#
# 5      Notify Release Request Yes No  \
# 28                               NaN
# 35                               NaN
# 40                               NaN
# 46                               NaN
# 47                               NaN
# ...                              ...
# 96824                            NaN
# 96834                            NaN
# 98216                            NaN
# 101881                           NaN
# 103624                           NaN
#
# 5                           TOD Current Duty Site   EID DTA ID  \
# 28      ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 35      ERO - Pacific Enforcement Response Center  b(6), b(7)c
# 40              DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 46             PHOENIX, AZ, DOCKET CONTROL OFFICE  b(6), b(7)c
# 47             PHOENIX, AZ, DOCKET CONTROL OFFICE  b(6), b(7)c
# ...                                           ...          ...
# 96824           DALLAS, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 96834      LOS ANGELES, CA, DOCKET CONTROL OFFICE  b(6), b(7)c
# 98216      ERO - Montgomery County, TX Sub Office  b(6), b(7)c
# 101881       HARLINGEN, TX, DOCKET CONTROL OFFICE  b(6), b(7)c
# 103624          ERO - Laredo, TX Detention Center  b(6), b(7)c
#
# 5                          Anonymized Identifier
# 28      00103f3e74679b755da13514ecf999d52ef39c4e
# 35      0015da563be4d6695f33804021144210bade49dd
# 40      00197c0df52a1bb3936347d6dc9816c997a2fb38
# 46      001d1303978e35d722d597f0e15f5692dd5286df
# 47      001d1303978e35d722d597f0e15f5692dd5286df
# ...                                          ...
# 96824   fff6a919573b3801f4824bfed092235e32c4f9d7
# 96834   fffb1d13fc1ac1fffd53bfcf81c6d66305e4863b
# 98216                                        NaN
# 101881                                       NaN
# 103624                                       NaN
#
# [93992 rows x 64 columns]

# %%
df_All2025.to_csv('FilteredData/All2025ICEDetainersData.csv', index=False)
