# %% [markdown]
# ## In. this notebook
# 1. Pull and combine all 2022 arrests data
# 2. Analyze it for:
#
#     a. arrests in year by state for 2022
#
#     b. arrests in NY for 2022
#
#     c. arrests in Capital Region for 2022

# %%
## import necessary libraries
import pandas as pd

# %%
df22 = pd.read_csv('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICE Arrests/CLEANED-ICEarrests-Albany/FilteredData/2022ICEArrestsData.csv', low_memory=False)
df22
# Out:
#          Apprehension Date Apprehension Type       State  County  \
# 0      2022-10-05 11:08:00               NaN    NEW YORK     NaN
# 1      2022-11-18 11:40:00               NaN  NEW JERSEY     NaN
# 2      2022-10-20 07:51:00               NaN     INDIANA     NaN
# 3      2022-12-14 08:50:00               NaN         NaN     NaN
# 4      2022-11-03 11:21:00               NaN    NEW YORK     NaN
# ...                    ...               ...         ...     ...
# 48624  2022-12-30 10:24:00               NaN       TEXAS     NaN
# 48625  2022-12-30 12:14:54               NaN         NaN     NaN
# 48626  2022-12-31 08:29:00               NaN       TEXAS     NaN
# 48627  2022-12-31 09:04:00               NaN       TEXAS     NaN
# 48628  2022-12-14 11:00:00               NaN         NaN     NaN
#
#                        TOA Current Duty AOR   Apprehension Final Program  \
# 0      New York City Area of Responsibility  Non-Detained Docket Control
# ...

# %%
df22_state = df22["State"].value_counts()
df22_state
# Out:
# TEXAS                             8007
# NEW JERSEY                        3406
# NEW YORK                          2600
# CALIFORNIA                        2510
# MASSACHUSETTS                     2298
# FLORIDA                           1849
# TENNESSEE                         1298
# COLORADO                          1094
# SOUTH CAROLINA                     694
# PENNSYLVANIA                       686
# NORTH CAROLINA                     667
# OHIO                               617
# UTAH                               605
# OKLAHOMA                           605
# WASHINGTON                         579
# GEORGIA                            566
# VIRGINIA                           554
# MARYLAND                           549
# LOUISIANA                          534
# ILLINOIS                           509
# ARIZONA                            474
# MAINE                              459
# NEBRASKA                           416
# ALABAMA                            388
# ...

# %%
df22_state.to_csv('FilteredData/2022DeportationByState.csv', index=True)

# %%
df_NY = df22.query('State == "NEW YORK"') 
df_NY
# Out:
#          Apprehension Date Apprehension Type     State  County  \
# 0      2022-10-05 11:08:00               NaN  NEW YORK     NaN
# 4      2022-11-03 11:21:00               NaN  NEW YORK     NaN
# 11     2022-11-28 12:22:00               NaN  NEW YORK     NaN
# 13     2022-10-26 13:43:00               NaN  NEW YORK     NaN
# 16     2022-10-12 13:26:00               NaN  NEW YORK     NaN
# ...                    ...               ...       ...     ...
# 47807  2022-10-18 12:31:00               NaN  NEW YORK     NaN
# 47811  2022-12-14 11:06:00               NaN  NEW YORK     NaN
# 47813  2022-12-05 15:06:00               NaN  NEW YORK     NaN
# 47858  2022-12-12 11:47:00               NaN  NEW YORK     NaN
# 48599  2022-12-20 06:15:00               NaN  NEW YORK     NaN
#
#                        TOA Current Duty AOR   Apprehension Final Program  \
# 0      New York City Area of Responsibility  Non-Detained Docket Control
# ...

# %%
NYcounts = df_NY['Apprehension Site Landmark'].value_counts()
NYcounts
# Out:
# NDD - 26 FEDERAL PLAZA NY, NY                             1859
# ERIE COUNTY                                                296
# CIP GENERAL AREA, NON-SPECIFIC                             105
# WENDE CORRECTIONAL FACILITY                                 78
# SARATOGA COUNTY                                             55
# ONONDAGA COUNTY                                             31
# FUGITIVE OPERATIONS NY STATE                                26
# FEDERAL CORRECTIONAL INSTITUTE RAY BROOK                    17
# NON-DETAINED AND JUVENILE                                   17
# ALBANY COUNTY                                               17
# CLINTON COUNTY                                              12
# CAP - BOP BROOKLYN NY STATE                                 12
# CAP - ORANGE COUNTY JAIL NY STATE                            6
# CAP - OTISVILLE FEDERAL CORRECTIONAL FACILITY NY STATE       5
# CAP - NASSAU COUNTY JAIL NY STATE                            5
# ...

# %%
NYcounts.to_csv('RawData/2022DeportationByNY.csv', index=True)

# %%
df_NY['Apprehension Site Landmark'].unique()
# Out:
# array(['NDD - 26 FEDERAL PLAZA NY, NY', 'ERIE COUNTY', 'SARATOGA COUNTY',
#        'FUGITIVE OPERATIONS NY STATE', 'BOP BROOKLYN', 'ONONDAGA COUNTY',
#        'ALBANY COUNTY', 'CIP GENERAL AREA, NON-SPECIFIC',
#        'FEDERAL CORRECTIONAL INSTITUTE RAY BROOK',
#        'WENDE CORRECTIONAL FACILITY', 'CAP - NASSAU COUNTY JAIL NY STATE',
#        'CLINTON COUNTY', 'CAP - NEWBURGH CITYPOLICE DEPARTMENT, NY STATE',
#        'CAP - BOP BROOKLYN NY STATE',
#        'CAP - SUFFOLK COUNTY JAIL NY STATE', 'ONEIDA COUNTY JAIL',
#        'CAP - ORANGE COUNTY SHERRIFF, NY STATE',
#        'CAP - USM - MANHATTAN NY State', 'NON-DETAINED and Juvenile',
#        'CAP - RAMAPO TOWN POLICE DEPARTMENT, NY STATE',
#        'NON-DETAINED AND JUVENILE', 'CAP - ORANGE COUNTY JAIL NY STATE',
#        'NBG GENERAL AREA, NON-SPECIFIC',
#        'CAP - USM - SOUTHERN DISTRICT NY STATE',
#        'BUFFALO GENERAL - Do Not Use', 'MONROE COUNTY',
#        'ERIE COUNTY JAIL', 'NIAGARA COUNTY JAIL',
# ...

# %%
CapitalRegion= ['ALBANY COUNTY','RENSSELAER COUNTY', 'SARATOGA COUNTY', 'GREENE COUNTY', 'WARREN COUNTY', 'WARREN COUNTY JAIL', 'SCHENECTADY COUNTY JAIL', 'SARATOGA COUNTY JAIL', 'RENSSELAER COUNTY JAIL', 'WASHINGTON CORRECTIONAL FACILITY', 'WASHINGTON COUNTY JAIL']

# %%
df_CR = df_NY[df_NY['Apprehension Site Landmark'].isin(CapitalRegion)]

# %%
df_CR
# Out:
#          Apprehension Date Apprehension Type     State  County  \
# 24     2022-12-14 00:00:00               NaN  NEW YORK     NaN
# 322    2022-10-13 09:30:00               NaN  NEW YORK     NaN
# 622    2022-10-04 10:28:00               NaN  NEW YORK     NaN
# 982    2022-11-29 11:26:00               NaN  NEW YORK     NaN
# 2479   2022-12-27 12:49:00               NaN  NEW YORK     NaN
# ...                    ...               ...       ...     ...
# 45392  2022-11-29 11:16:00               NaN  NEW YORK     NaN
# 45738  2022-10-26 12:47:00               NaN  NEW YORK     NaN
# 45766  2022-12-06 09:43:00               NaN  NEW YORK     NaN
# 46498  2022-11-02 12:19:00               NaN  NEW YORK     NaN
# 46934  2022-11-15 11:13:00               NaN  NEW YORK     NaN
#
#                  TOA Current Duty AOR   Apprehension Final Program  \
# 24     Buffalo Area of Responsibility  Non-Detained Docket Control
# 322    Buffalo Area of Responsibility   ERO Criminal Alien Program
# ...

# %%
df_CR.to_csv('FilteredData/2022CapitalRegionICEArrests.csv', index = True)

# %%
df_CR["Apprehension Site Landmark"].value_counts()
# Out:
# SARATOGA COUNTY            55
# ALBANY COUNTY              17
# SCHENECTADY COUNTY JAIL     2
# GREENE COUNTY               1
# RENSSELAER COUNTY JAIL      1
# Name: Apprehension Site Landmark, dtype: int64
